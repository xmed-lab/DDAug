# %%
import numpy as np 
import matplotlib.pyplot as plt 

from training.data_augmentation.model import MCTS_Augment

# %%
data = np.array([1 / (each+1) for each in range(1, 1001)])
noise = np.random.normal(0.1, 0.01, size=(1000, ))
score = data + noise

# plt.figure(figsize=(20, 10))
# plt.plot(range(1000), score)

# %%
search_augment = MCTS_Augment((64, 320, 240), None)

# %%
for each_index, each in enumerate(score):
    out_str, _ = search_augment.update_epoch(each)
    search_augment.build_callable()
    print(each_index, out_str, '\n', search_augment.traverse_path)
# Out:
# 0
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [10, 10, 9]
# 1
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [7, 10, 3]
# 2
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [11, 11, 9]
# 3
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [3, 6, 12]
# 4
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [1, 12, 5]
# 5
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [10, 8, 2]
# 6
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [7, 1, 6]
# 7
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [16, 4, 8]
# 8
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 8, 9]
# 9
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 5, 10]
# 10
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 5, 5]
# 11
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 12, 0]
# 12
# bad score +1 with path: [15, 12, 0]
# bad score +1 with path: [15, 12, 0]
# bad score +1 with path: [15, 12, 0]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 12, 6]
# 13
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 12, 6]
# 14
# bad score +1 with path: [15, 12, 6]
# bad score +1 with path: [15, 12, 6]
# bad score +1 with path: [15, 12, 6]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [16, 2, 5]
# 15
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [5, 11, 4]
# 16
# bad score +1 with path: [5, 11, 4]
# bad score +1 with path: [5, 11, 4]
# bad score +1 with path: [5, 11, 4]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 13, 0]
# 17
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [9, 5, 6]
# 18
# bad score +1 with path: [9, 5, 6]
# bad score +1 with path: [9, 5, 6]
# bad score +1 with path: [9, 5, 6]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [3, 0, 2]
# 19
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 6, 8]
# 20
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 2, 10]
# 21
# bad score reset with layer: 1 | node index: 15 | path: [15, 2, 10]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 8, 9]
# 22
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [13, 12, 12]
# 23
# bad score +1 with path: [13, 12, 12]
# bad score +1 with path: [13, 12, 12]
# bad score +1 with path: [13, 12, 12]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [13, 1, 2]
# 24
# bad score reset with layer: 1 | node index: 13 | path: [13, 1, 2]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [3, 6, 9]
# 25
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [10, 7, 13]
# 26
# bad score +1 with path: [10, 7, 13]
# bad score +1 with path: [10, 7, 13]
# bad score +1 with path: [10, 7, 13]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 2, 0]
# 27
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [0, 10, 10]
# 28
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [11, 14, 13]
# 29
# bad score +1 with path: [11, 14, 13]
# bad score +1 with path: [11, 14, 13]
# bad score +1 with path: [11, 14, 13]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 13, 5]
# 30
# bad score +1 with path: [12, 13, 5]
# bad score +1 with path: [12, 13, 5]
# bad score +1 with path: [12, 13, 5]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 6, 2]
# 31
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 0, 11]
# 32
# bad score reset with layer: 1 | node index: 12 | path: [12, 0, 11]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 5, 11]
# 33
# bad score +1 with path: [8, 5, 11]
# bad score +1 with path: [8, 5, 11]
# bad score +1 with path: [8, 5, 11]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 7, 10]
# 34
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 7, 5]
# 35
# bad score +1 with path: [12, 7, 5]
# bad score +1 with path: [12, 7, 5]
# bad score +1 with path: [12, 7, 5]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [1, 13, 5]
# 36
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [4, 1, 10]
# 37
# bad score +1 with path: [4, 1, 10]
# bad score +1 with path: [4, 1, 10]
# bad score +1 with path: [4, 1, 10]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 2, 7]
# 38
# bad score +1 with path: [8, 2, 7]
# bad score +1 with path: [8, 2, 7]
# bad score +1 with path: [8, 2, 7]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [3, 11, 6]
# 39
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 10, 4]
# 40
# bad score +1 with path: [2, 10, 4]
# bad score +1 with path: [2, 10, 4]
# bad score +1 with path: [2, 10, 4]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [7, 9, 7]
# 41
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 13, 9]
# 42
# bad score +1 with path: [2, 13, 9]
# bad score +1 with path: [2, 13, 9]
# bad score +1 with path: [2, 13, 9]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 10, 8]
# 43
# bad score reset with layer: 1 | node index: 8 | path: [8, 10, 8]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 14, 8]
# 44
# bad score +1 with path: [8, 14, 8]
# bad score +1 with path: [8, 14, 8]
# bad score +1 with path: [8, 14, 8]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [14, 11, 10]
# 45
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 2, 2]
# 46
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [14, 6, 4]
# 47
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [3, 14, 4]
# 48
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [0, 13, 13]
# 49
# bad score +1 with path: [0, 13, 13]
# bad score +1 with path: [0, 13, 13]
# bad score +1 with path: [0, 13, 13]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [10, 0, 3]
# 50
# bad score +1 with path: [10, 0, 3]
# bad score +1 with path: [10, 0, 3]
# bad score +1 with path: [10, 0, 3]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [5, 13, 9]
# 51
# bad score +1 with path: [5, 13, 9]
# bad score +1 with path: [5, 13, 9]
# bad score +1 with path: [5, 13, 9]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [16, 7, 12]
# 52
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 15, 9]
# 53
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [6, 2, 7]
# 54
# bad score +1 with path: [6, 2, 7]
# bad score +1 with path: [6, 2, 7]
# bad score +1 with path: [6, 2, 7]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [1, 2, 7]
# 55
# bad score +1 with path: [1, 2, 7]
# bad score +1 with path: [1, 2, 7]
# bad score +1 with path: [1, 2, 7]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [7, 13, 2]
# 56
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [9, 4, 5]
# 57
# bad score +1 with path: [9, 4, 5]
# bad score +1 with path: [9, 4, 5]
# bad score +1 with path: [9, 4, 5]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [6, 8, 11]
# 58
# bad score reset with layer: 1 | node index: 6 | path: [6, 8, 11]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 12, 10]
# 59
# bad score +1 with path: [12, 12, 10]
# bad score +1 with path: [12, 12, 10]
# bad score +1 with path: [12, 12, 10]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [7, 7, 8]
# 60
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [13, 2, 7]
# 61
# bad score +1 with path: [13, 2, 7]
# bad score +1 with path: [13, 2, 7]
# bad score +1 with path: [13, 2, 7]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 14, 7]
# 62
# bad score reset with layer: 1 | node index: 12 | path: [12, 14, 7]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [13, 0, 7]
# 63
# bad score reset with layer: 1 | node index: 13 | path: [13, 0, 7]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [9, 14, 9]
# 64
# bad score +1 with path: [9, 14, 9]
# bad score +1 with path: [9, 14, 9]
# bad score +1 with path: [9, 14, 9]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 3, 6]
# 65
# bad score +1 with path: [15, 3, 6]
# bad score +1 with path: [15, 3, 6]
# bad score +1 with path: [15, 3, 6]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 2, 2]
# 66
# bad score +1 with path: [12, 2, 2]
# bad score +1 with path: [12, 2, 2]
# bad score +1 with path: [12, 2, 2]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 2, 6]
# 67
# bad score reset with layer: 1 | node index: 15 | path: [15, 2, 6]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [3, 13, 0]
# 68
# bad score +1 with path: [3, 13, 0]
# bad score +1 with path: [3, 13, 0]
# bad score +1 with path: [3, 13, 0]
# uniform sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [2, 5, 1]
# 69
# bad score reset with layer: 1 | node index: 2 | path: [2, 5, 1]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [5, 5, 8]
# 70
# bad score +1 with path: [5, 5, 8]
# bad score +1 with path: [5, 5, 8]
# bad score +1 with path: [5, 5, 8]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [0, 14, 6]
# 71
# bad score +1 with path: [0, 14, 6]
# bad score +1 with path: [0, 14, 6]
# bad score +1 with path: [0, 14, 6]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [7, 7, 5]
# 72
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [5, 8, 6]
# 73
# bad score +1 with path: [5, 8, 6]
# bad score +1 with path: [5, 8, 6]
# bad score +1 with path: [5, 8, 6]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [12, 5, 1]
# 74
# bad score +1 with path: [12, 5, 1]
# bad score +1 with path: [12, 5, 1]
# bad score +1 with path: [12, 5, 1]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [13, 10, 8]
# 75
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [4, 4, 12]
# 76
# bad score +1 with path: [4, 4, 12]
# bad score +1 with path: [4, 4, 12]
# bad score +1 with path: [4, 4, 12]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [4, 2, 2]
# 77
# bad score +1 with path: [4, 2, 2]
# bad score +1 with path: [4, 2, 2]
# bad score +1 with path: [4, 2, 2]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [13, 1, 4]
# 78
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [15, 5, 5]
# 79
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [8, 11, 9]
# 80
# bad score +1 with path: [8, 11, 9]
# bad score +1 with path: [8, 11, 9]
# bad score +1 with path: [8, 11, 9]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [11, 6, 11]
# 81
# bad score reset with layer: 1 | node index: 11 | path: [11, 6, 11]
#     uct sampling at layer 1, tree have 17 nodes
# uniform sampling at layer 2, tree have 256 nodes
# uniform sampling at layer 3, tree have 3372 nodes
#  [5, 3, 0]
# 82
# bad score +1 with path: [5, 3, 0]
# removed node at layer: 1 with index: 5, object: node opt: BrightnessMultiplicativeTransform   with: {'multiplier_range': (1, 1.5), 'p_per_sample': 0.8}
# bad score +1 with path: [5, 3, 0]
# bad score +1 with path: [5, 3, 0]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [4, 6, 10]
# 83
# bad score +1 with path: [4, 6, 10]
# bad score +1 with path: [4, 6, 10]
# bad score +1 with path: [4, 6, 10]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [13, 9, 9]
# 84
# bad score +1 with path: [13, 9, 9]
# bad score +1 with path: [13, 9, 9]
# bad score +1 with path: [13, 9, 9]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [6, 9, 1]
# 85
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [12, 1, 12]
# 86
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [12, 12, 0]
# 87
# bad score reset with layer: 2 | node index: 12 | path: [12, 12, 0]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [2, 8, 9]
# 88
# bad score +1 with path: [2, 8, 9]
# bad score +1 with path: [2, 8, 9]
# bad score +1 with path: [2, 8, 9]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [6, 5, 1]
# 89
# bad score +1 with path: [6, 5, 1]
# bad score +1 with path: [6, 5, 1]
# bad score +1 with path: [6, 5, 1]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [8, 11, 11]
# 90
# bad score reset with layer: 1 | node index: 8 | path: [8, 11, 11]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [0, 10, 8]
# 91
# bad score +1 with path: [0, 10, 8]
# bad score +1 with path: [0, 10, 8]
# bad score +1 with path: [0, 10, 8]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [15, 15, 7]
# 92
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [8, 5, 6]
# 93
# bad score reset with layer: 2 | node index: 5 | path: [8, 5, 6]
# bad score reset with layer: 3 | node index: 6 | path: [8, 5, 6]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [0, 8, 2]
# 94
# bad score +1 with path: [0, 8, 2]
# bad score +1 with path: [0, 8, 2]
# bad score +1 with path: [0, 8, 2]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [1, 14, 8]
# 95
# bad score reset with layer: 1 | node index: 1 | path: [1, 14, 8]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [10, 4, 4]
# 96
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [5, 8, 8]
# 97
# bad score +1 with path: [5, 8, 8]
# bad score +1 with path: [5, 8, 8]
# bad score +1 with path: [5, 8, 8]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [0, 2, 11]
# 98
# bad score reset with layer: 1 | node index: 0 | path: [0, 2, 11]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [11, 7, 13]
# 99
# bad score +1 with path: [11, 7, 13]
# bad score +1 with path: [11, 7, 13]
# bad score +1 with path: [11, 7, 13]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [2, 1, 4]
# 100
# bad score +1 with path: [2, 1, 4]
# bad score +1 with path: [2, 1, 4]
# bad score +1 with path: [2, 1, 4]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [5, 11, 4]
# 101
# bad score +1 with path: [5, 11, 4]
# bad score +1 with path: [5, 11, 4]
# bad score +1 with path: [5, 11, 4]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [4, 2, 3]
# 102
# bad score reset with layer: 1 | node index: 4 | path: [4, 2, 3]
# bad score reset with layer: 2 | node index: 2 | path: [4, 2, 3]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [6, 6, 8]
# 103
# bad score reset with layer: 1 | node index: 6 | path: [6, 6, 8]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [0, 9, 4]
# 104
# bad score +1 with path: [0, 9, 4]
# bad score +1 with path: [0, 9, 4]
# bad score +1 with path: [0, 9, 4]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [1, 9, 4]
# 105
# bad score +1 with path: [1, 9, 4]
# bad score +1 with path: [1, 9, 4]
# bad score +1 with path: [1, 9, 4]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [10, 2, 7]
# 106
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [12, 12, 0]
# 107
# bad score +1 with path: [12, 12, 0]
# bad score +1 with path: [12, 12, 0]
# bad score +1 with path: [12, 12, 0]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [8, 2, 3]
# 108
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [7, 3, 5]
# 109
# bad score +1 with path: [7, 3, 5]
# bad score +1 with path: [7, 3, 5]
# bad score +1 with path: [7, 3, 5]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [4, 8, 8]
# 110
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [14, 7, 2]
# 111
# bad score +1 with path: [14, 7, 2]
# bad score +1 with path: [14, 7, 2]
# bad score +1 with path: [14, 7, 2]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [15, 10, 9]
# 112
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [7, 13, 5]
# 113
# bad score +1 with path: [7, 13, 5]
# bad score +1 with path: [7, 13, 5]
# bad score +1 with path: [7, 13, 5]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [2, 2, 11]
# 114
# bad score +1 with path: [2, 2, 11]
# bad score +1 with path: [2, 2, 11]
# bad score +1 with path: [2, 2, 11]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [15, 5, 3]
# 115
# bad score +1 with path: [15, 5, 3]
# bad score +1 with path: [15, 5, 3]
# bad score +1 with path: [15, 5, 3]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [6, 3, 5]
# 116
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [15, 10, 10]
# 117
# bad score +1 with path: [15, 10, 10]
# bad score +1 with path: [15, 10, 10]
# bad score +1 with path: [15, 10, 10]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [4, 3, 6]
# 118
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [13, 10, 3]
# 119
# bad score +1 with path: [13, 10, 3]
# bad score +1 with path: [13, 10, 3]
# bad score +1 with path: [13, 10, 3]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [6, 11, 12]
# 120
# bad score +1 with path: [6, 11, 12]
# bad score +1 with path: [6, 11, 12]
# bad score +1 with path: [6, 11, 12]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [9, 1, 1]
# 121
# bad score reset with layer: 1 | node index: 9 | path: [9, 1, 1]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [8, 12, 0]
# 122
# bad score +1 with path: [8, 12, 0]
# bad score +1 with path: [8, 12, 0]
# bad score +1 with path: [8, 12, 0]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [11, 0, 10]
# 123
# bad score reset with layer: 1 | node index: 11 | path: [11, 0, 10]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [14, 1, 4]
# 124
# bad score reset with layer: 1 | node index: 14 | path: [14, 1, 4]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [9, 8, 5]
# 125
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [13, 0, 10]
# 126
# bad score +1 with path: [13, 0, 10]
# bad score +1 with path: [13, 0, 10]
# bad score +1 with path: [13, 0, 10]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [4, 8, 5]
# 127
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [10, 9, 6]
# 128
# bad score +1 with path: [10, 9, 6]
# bad score +1 with path: [10, 9, 6]
# bad score +1 with path: [10, 9, 6]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [12, 0, 12]
# 129
# bad score reset with layer: 1 | node index: 12 | path: [12, 0, 12]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [15, 13, 6]
# 130
# bad score reset with layer: 1 | node index: 15 | path: [15, 13, 6]
#     uct sampling at layer 1, tree have 16 nodes
# uniform sampling at layer 2, tree have 242 nodes
# uniform sampling at layer 3, tree have 3200 nodes
#  [7, 12, 3]
# 131
# bad score +1 with path: [7, 12, 3]
# removed node at layer: 1 with index: 7, object: node opt: GaussianBlurTransform               with: {'blur_sigma': (0.5, 1), 'p_per_channel': 1, 'p_per_sample': 0.8}
# bad score +1 with path: [7, 12, 3]
# bad score +1 with path: [7, 12, 3]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [4, 3, 5]
# 132
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [12, 13, 1]
# 133
# bad score reset with layer: 1 | node index: 12 | path: [12, 13, 1]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [10, 14, 2]
# 134
# bad score +1 with path: [10, 14, 2]
# bad score +1 with path: [10, 14, 2]
# bad score +1 with path: [10, 14, 2]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [14, 11, 7]
# 135
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [12, 1, 12]
# 136
# bad score +1 with path: [12, 1, 12]
# bad score +1 with path: [12, 1, 12]
# bad score +1 with path: [12, 1, 12]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [2, 0, 0]
# 137
# bad score reset with layer: 1 | node index: 2 | path: [2, 0, 0]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [2, 9, 5]
# 138
# bad score +1 with path: [2, 9, 5]
# bad score +1 with path: [2, 9, 5]
# bad score +1 with path: [2, 9, 5]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [9, 12, 4]
# 139
# bad score reset with layer: 1 | node index: 9 | path: [9, 12, 4]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [14, 8, 10]
# 140
# bad score +1 with path: [14, 8, 10]
# bad score +1 with path: [14, 8, 10]
# bad score +1 with path: [14, 8, 10]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [11, 0, 5]
# 141
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [5, 3, 2]
# 142
# bad score reset with layer: 1 | node index: 5 | path: [5, 3, 2]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [9, 0, 1]
# 143
# bad score +1 with path: [9, 0, 1]
# bad score +1 with path: [9, 0, 1]
# bad score +1 with path: [9, 0, 1]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [8, 10, 6]
# 144
# bad score +1 with path: [8, 10, 6]
# bad score +1 with path: [8, 10, 6]
# bad score +1 with path: [8, 10, 6]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [13, 3, 12]
# 145
# bad score reset with layer: 2 | node index: 3 | path: [13, 3, 12]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [3, 3, 4]
# 146
# bad score +1 with path: [3, 3, 4]
# bad score +1 with path: [3, 3, 4]
# bad score +1 with path: [3, 3, 4]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [0, 9, 4]
# 147
# bad score reset with layer: 1 | node index: 0 | path: [0, 9, 4]
# bad score reset with layer: 2 | node index: 9 | path: [0, 9, 4]
# bad score reset with layer: 3 | node index: 4 | path: [0, 9, 4]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [8, 12, 1]
# 148
# bad score reset with layer: 1 | node index: 8 | path: [8, 12, 1]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [4, 9, 1]
# 149
# bad score +1 with path: [4, 9, 1]
# bad score +1 with path: [4, 9, 1]
# bad score +1 with path: [4, 9, 1]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [5, 5, 9]
# 150
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [11, 3, 0]
# 151
# bad score +1 with path: [11, 3, 0]
# bad score +1 with path: [11, 3, 0]
# bad score +1 with path: [11, 3, 0]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [4, 0, 10]
# 152
# bad score +1 with path: [4, 0, 10]
# bad score +1 with path: [4, 0, 10]
# bad score +1 with path: [4, 0, 10]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [12, 8, 13]
# 153
# bad score +1 with path: [12, 8, 13]
# bad score +1 with path: [12, 8, 13]
# bad score +1 with path: [12, 8, 13]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [3, 11, 4]
# 154
# bad score +1 with path: [3, 11, 4]
# bad score +1 with path: [3, 11, 4]
# bad score +1 with path: [3, 11, 4]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [13, 10, 12]
# 155
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [0, 14, 3]
# 156
# bad score +1 with path: [0, 14, 3]
# bad score +1 with path: [0, 14, 3]
# bad score +1 with path: [0, 14, 3]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [4, 10, 10]
# 157
# bad score reset with layer: 1 | node index: 4 | path: [4, 10, 10]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [11, 14, 9]
# 158
# bad score reset with layer: 1 | node index: 11 | path: [11, 14, 9]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [14, 11, 0]
# 159
# bad score +1 with path: [14, 11, 0]
# bad score +1 with path: [14, 11, 0]
# bad score +1 with path: [14, 11, 0]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [2, 13, 3]
# 160
# bad score +1 with path: [2, 13, 3]
# bad score +1 with path: [2, 13, 3]
# bad score +1 with path: [2, 13, 3]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [2, 11, 5]
# 161
# bad score reset with layer: 1 | node index: 2 | path: [2, 11, 5]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [11, 13, 8]
# 162
# bad score +1 with path: [11, 13, 8]
# bad score +1 with path: [11, 13, 8]
# bad score +1 with path: [11, 13, 8]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [9, 10, 8]
# 163
# bad score reset with layer: 1 | node index: 9 | path: [9, 10, 8]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [14, 14, 4]
# 164
# bad score +1 with path: [14, 14, 4]
# bad score +1 with path: [14, 14, 4]
# bad score +1 with path: [14, 14, 4]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [9, 0, 0]
# 165
# bad score +1 with path: [9, 0, 0]
# bad score +1 with path: [9, 0, 0]
# bad score +1 with path: [9, 0, 0]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [9, 4, 6]
# 166
# bad score reset with layer: 1 | node index: 9 | path: [9, 4, 6]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [2, 13, 13]
# 167
# bad score +1 with path: [2, 13, 13]
# bad score +1 with path: [2, 13, 13]
# bad score +1 with path: [2, 13, 13]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [3, 7, 7]
# 168
# bad score +1 with path: [3, 7, 7]
# bad score +1 with path: [3, 7, 7]
# bad score +1 with path: [3, 7, 7]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [1, 4, 11]
# 169
# bad score reset with layer: 1 | node index: 1 | path: [1, 4, 11]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [3, 4, 11]
# 170
# bad score reset with layer: 1 | node index: 3 | path: [3, 4, 11]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [8, 6, 10]
# 171
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [4, 7, 4]
# 172
# bad score +1 with path: [4, 7, 4]
# bad score +1 with path: [4, 7, 4]
# bad score +1 with path: [4, 7, 4]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [14, 10, 0]
# 173
# bad score +1 with path: [14, 10, 0]
# bad score +1 with path: [14, 10, 0]
# bad score +1 with path: [14, 10, 0]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [4, 12, 8]
# 174
# bad score reset with layer: 1 | node index: 4 | path: [4, 12, 8]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [10, 12, 11]
# 175
# bad score +1 with path: [10, 12, 11]
# bad score +1 with path: [10, 12, 11]
# bad score +1 with path: [10, 12, 11]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [0, 12, 3]
# 176
# bad score +1 with path: [0, 12, 3]
# bad score +1 with path: [0, 12, 3]
# bad score +1 with path: [0, 12, 3]
#     uct sampling at layer 1, tree have 15 nodes
# uniform sampling at layer 2, tree have 227 nodes
# uniform sampling at layer 3, tree have 3004 nodes
#  [14, 4, 10]
# 177
# bad score +1 with path: [14, 4, 10]
# removed node at layer: 1 with index: 14, object: node opt: GridDistortion                      with: {}
# bad score +1 with path: [14, 4, 10]
# bad score +1 with path: [14, 4, 10]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [10, 2, 6]
# 178
# bad score reset with layer: 1 | node index: 10 | path: [10, 2, 6]
# bad score reset with layer: 2 | node index: 2 | path: [10, 2, 6]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [3, 6, 2]
# 179
# bad score +1 with path: [3, 6, 2]
# bad score +1 with path: [3, 6, 2]
# bad score +1 with path: [3, 6, 2]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [1, 3, 7]
# 180
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [5, 2, 9]
# 181
# bad score reset with layer: 2 | node index: 2 | path: [5, 2, 9]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [12, 15, 4]
# 182
# bad score +1 with path: [12, 15, 4]
# bad score +1 with path: [12, 15, 4]
# bad score +1 with path: [12, 15, 4]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [0, 10, 12]
# 183
# bad score reset with layer: 1 | node index: 0 | path: [0, 10, 12]
# bad score reset with layer: 2 | node index: 10 | path: [0, 10, 12]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [1, 0, 10]
# 184
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [6, 13, 9]
# 185
# bad score +1 with path: [6, 13, 9]
# bad score +1 with path: [6, 13, 9]
# bad score +1 with path: [6, 13, 9]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [5, 12, 5]
# 186
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [6, 2, 0]
# 187
# bad score reset with layer: 1 | node index: 6 | path: [6, 2, 0]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [11, 12, 3]
# 188
# bad score reset with layer: 1 | node index: 11 | path: [11, 12, 3]
# bad score reset with layer: 2 | node index: 12 | path: [11, 12, 3]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [5, 2, 5]
# 189
# bad score +1 with path: [5, 2, 5]
# bad score +1 with path: [5, 2, 5]
# bad score +1 with path: [5, 2, 5]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [7, 2, 3]
# 190
# bad score reset with layer: 1 | node index: 7 | path: [7, 2, 3]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [3, 4, 1]
# 191
# bad score reset with layer: 1 | node index: 3 | path: [3, 4, 1]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [10, 9, 0]
# 192
# bad score +1 with path: [10, 9, 0]
# bad score +1 with path: [10, 9, 0]
# bad score +1 with path: [10, 9, 0]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [3, 11, 7]
# 193
# bad score reset with layer: 2 | node index: 11 | path: [3, 11, 7]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [0, 11, 1]
# 194
# bad score +1 with path: [0, 11, 1]
# bad score +1 with path: [0, 11, 1]
# bad score +1 with path: [0, 11, 1]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [13, 6, 7]
# 195
# bad score +1 with path: [13, 6, 7]
# bad score +1 with path: [13, 6, 7]
# bad score +1 with path: [13, 6, 7]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [9, 13, 13]
# 196
# bad score +1 with path: [9, 13, 13]
# bad score +1 with path: [9, 13, 13]
# bad score +1 with path: [9, 13, 13]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [1, 14, 11]
# 197
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [0, 4, 8]
# 198
# bad score reset with layer: 1 | node index: 0 | path: [0, 4, 8]
#     uct sampling at layer 1, tree have 14 nodes
# uniform sampling at layer 2, tree have 211 nodes
# uniform sampling at layer 3, tree have 2780 nodes
#  [0, 8, 4]
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.1477, percentile: 5.00%, currently pruning 9.30% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.2495, percentile: 10.00%, currently pruning 13.62% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.2740, percentile: 15.00%, currently pruning 17.94% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.3060, percentile: 20.00%, currently pruning 22.59% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.3431, percentile: 25.00%, currently pruning 27.91% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.3970, percentile: 30.00%, currently pruning 33.89% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 1.5197, percentile: 35.00%, currently pruning 41.53% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# guarded layer 1 nodes, will only prune 1 node
# 199
# bad score +1 with path: [0, 8, 4]
# bad score +1 with path: [0, 8, 4]
# bad score +1 with path: [0, 8, 4]
# pruning at uct percentile 1.5197
#     uct sampling at layer 1, tree have 13 nodes
# uniform sampling at layer 2, tree have 191 nodes
# uniform sampling at layer 3, tree have 2440 nodes
#  [2, 7, 7]
# 200
# bad score +1 with path: [2, 7, 7]
# bad score +1 with path: [2, 7, 7]
# bad score +1 with path: [2, 7, 7]
#     uct sampling at layer 1, tree have 13 nodes
# uniform sampling at layer 2, tree have 191 nodes
# ...
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 1, 3]
# 939
# bad score +1 with path: [2, 1, 3]
# bad score +1 with path: [2, 1, 3]
# bad score +1 with path: [2, 1, 3]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 3, 6]
# 940
# bad score reset with layer: 1 | node index: 2 | path: [2, 3, 6]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 1, 1]
# 941
# bad score +1 with path: [0, 1, 1]
# bad score +1 with path: [0, 1, 1]
# bad score +1 with path: [0, 1, 1]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 3, 8]
# 942
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [3, 1, 10]
# 943
# bad score reset with layer: 1 | node index: 3 | path: [3, 1, 10]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 3, 2]
# 944
# bad score reset with layer: 2 | node index: 3 | path: [1, 3, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 0, 2]
# 945
# bad score +1 with path: [2, 0, 2]
# bad score +1 with path: [2, 0, 2]
# bad score +1 with path: [2, 0, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 3, 2]
# 946
# bad score +1 with path: [2, 3, 2]
# bad score +1 with path: [2, 3, 2]
# bad score +1 with path: [2, 3, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 2, 7]
# 947
# bad score reset with layer: 1 | node index: 0 | path: [0, 2, 7]
# bad score reset with layer: 2 | node index: 2 | path: [0, 2, 7]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 8, 7]
# 948
# bad score reset with layer: 2 | node index: 8 | path: [1, 8, 7]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 1, 11]
# 949
# bad score reset with layer: 2 | node index: 1 | path: [0, 1, 11]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 6, 0]
# 950
# bad score +1 with path: [1, 6, 0]
# bad score +1 with path: [1, 6, 0]
# bad score +1 with path: [1, 6, 0]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 4, 5]
# 951
# bad score reset with layer: 1 | node index: 1 | path: [1, 4, 5]
# bad score reset with layer: 2 | node index: 4 | path: [1, 4, 5]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 1, 4]
# 952
# bad score reset with layer: 3 | node index: 4 | path: [0, 1, 4]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 0, 5]
# 953
# bad score +1 with path: [1, 0, 5]
# bad score +1 with path: [1, 0, 5]
# bad score +1 with path: [1, 0, 5]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [3, 0, 11]
# 954
# bad score +1 with path: [3, 0, 11]
# bad score +1 with path: [3, 0, 11]
# bad score +1 with path: [3, 0, 11]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 1, 8]
# 955
# bad score +1 with path: [0, 1, 8]
# bad score +1 with path: [0, 1, 8]
# bad score +1 with path: [0, 1, 8]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 4, 6]
# 956
# bad score reset with layer: 1 | node index: 1 | path: [1, 4, 6]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [3, 4, 10]
# 957
# bad score +1 with path: [3, 4, 10]
# bad score +1 with path: [3, 4, 10]
# bad score +1 with path: [3, 4, 10]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 8, 10]
# 958
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 2, 13]
# 959
# bad score +1 with path: [2, 2, 13]
# bad score +1 with path: [2, 2, 13]
# bad score +1 with path: [2, 2, 13]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 5, 7]
# 960
# bad score reset with layer: 1 | node index: 2 | path: [2, 5, 7]
# bad score reset with layer: 2 | node index: 5 | path: [2, 5, 7]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [0, 0, 0]
# 961
# bad score +1 with path: [0, 0, 0]
# bad score +1 with path: [0, 0, 0]
# bad score +1 with path: [0, 0, 0]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 2, 2]
# 962
# bad score reset with layer: 2 | node index: 2 | path: [2, 2, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [1, 4, 5]
# 963
# bad score +1 with path: [1, 4, 5]
# bad score +1 with path: [1, 4, 5]
# bad score +1 with path: [1, 4, 5]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [3, 0, 9]
# 964
# bad score +1 with path: [3, 0, 9]
# bad score +1 with path: [3, 0, 9]
# bad score +1 with path: [3, 0, 9]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 4, 11]
# 965
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 1, 10]
# 966
# bad score +1 with path: [0, 1, 10]
# bad score +1 with path: [0, 1, 10]
# bad score +1 with path: [0, 1, 10]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [0, 0, 8]
# 967
# bad score +1 with path: [0, 0, 8]
# bad score +1 with path: [0, 0, 8]
# bad score +1 with path: [0, 0, 8]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
#     uct sampling at layer 3, tree have 339 nodes
#  [0, 1, 7]
# 968
# bad score reset with layer: 1 | node index: 0 | path: [0, 1, 7]
# bad score reset with layer: 2 | node index: 1 | path: [0, 1, 7]
# bad score reset with layer: 3 | node index: 7 | path: [0, 1, 7]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 27 nodes
# uniform sampling at layer 3, tree have 339 nodes
#  [2, 1, 1]
# 969
# bad score +1 with path: [2, 1, 1]
# bad score +1 with path: [2, 1, 1]
# removed node at layer: 2 with index: 1, object: node opt: GammaTransform                      with: {'gamma_range': (1, 1.5), 'per_channel': False, 'retain_stats': True, 'p_per_sample': 0.8}
# bad score +1 with path: [2, 1, 1]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [2, 4, 2]
# 970
# bad score +1 with path: [2, 4, 2]
# bad score +1 with path: [2, 4, 2]
# bad score +1 with path: [2, 4, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 1, 4]
# 971
# bad score +1 with path: [1, 1, 4]
# bad score +1 with path: [1, 1, 4]
# bad score +1 with path: [1, 1, 4]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [3, 2, 0]
# 972
# bad score reset with layer: 1 | node index: 3 | path: [3, 2, 0]
# bad score reset with layer: 2 | node index: 2 | path: [3, 2, 0]
# bad score reset with layer: 3 | node index: 0 | path: [3, 2, 0]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 8, 9]
# 973
# bad score reset with layer: 1 | node index: 1 | path: [1, 8, 9]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [3, 1, 10]
# 974
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [3, 5, 6]
# 975
# bad score +1 with path: [3, 5, 6]
# bad score +1 with path: [3, 5, 6]
# bad score +1 with path: [3, 5, 6]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 4, 0]
# 976
# bad score reset with layer: 2 | node index: 4 | path: [1, 4, 0]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [3, 4, 5]
# 977
# bad score +1 with path: [3, 4, 5]
# bad score +1 with path: [3, 4, 5]
# bad score +1 with path: [3, 4, 5]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 7, 1]
# 978
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [0, 1, 8]
# 979
# bad score +1 with path: [0, 1, 8]
# bad score +1 with path: [0, 1, 8]
# bad score +1 with path: [0, 1, 8]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [0, 2, 8]
# 980
# bad score +1 with path: [0, 2, 8]
# bad score +1 with path: [0, 2, 8]
# bad score +1 with path: [0, 2, 8]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [0, 2, 2]
# 981
# bad score +1 with path: [0, 2, 2]
# bad score +1 with path: [0, 2, 2]
# bad score +1 with path: [0, 2, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 8, 3]
# 982
# bad score reset with layer: 3 | node index: 3 | path: [1, 8, 3]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 3, 10]
# 983
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [2, 3, 6]
# 984
# bad score +1 with path: [2, 3, 6]
# bad score +1 with path: [2, 3, 6]
# bad score +1 with path: [2, 3, 6]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [3, 1, 12]
# 985
# bad score reset with layer: 1 | node index: 3 | path: [3, 1, 12]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [0, 0, 1]
# 986
# bad score +1 with path: [0, 0, 1]
# bad score +1 with path: [0, 0, 1]
# bad score +1 with path: [0, 0, 1]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [0, 1, 8]
# 987
# bad score reset with layer: 1 | node index: 0 | path: [0, 1, 8]
# bad score reset with layer: 2 | node index: 1 | path: [0, 1, 8]
# bad score reset with layer: 3 | node index: 8 | path: [0, 1, 8]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [2, 2, 3]
# 988
# bad score +1 with path: [2, 2, 3]
# bad score +1 with path: [2, 2, 3]
# bad score +1 with path: [2, 2, 3]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [3, 7, 4]
# 989
# bad score reset with layer: 2 | node index: 7 | path: [3, 7, 4]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [2, 1, 9]
# 990
# bad score reset with layer: 1 | node index: 2 | path: [2, 1, 9]
# bad score reset with layer: 3 | node index: 9 | path: [2, 1, 9]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [0, 2, 3]
# 991
# bad score reset with layer: 2 | node index: 2 | path: [0, 2, 3]
# bad score reset with layer: 3 | node index: 3 | path: [0, 2, 3]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 7, 3]
# 992
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [2, 0, 5]
# 993
# bad score +1 with path: [2, 0, 5]
# bad score +1 with path: [2, 0, 5]
# bad score +1 with path: [2, 0, 5]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [2, 4, 11]
# 994
# bad score +1 with path: [2, 4, 11]
# bad score +1 with path: [2, 4, 11]
# bad score +1 with path: [2, 4, 11]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [0, 0, 6]
# 995
# bad score +1 with path: [0, 0, 6]
# bad score +1 with path: [0, 0, 6]
# bad score +1 with path: [0, 0, 6]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [2, 0, 2]
# 996
# bad score reset with layer: 1 | node index: 2 | path: [2, 0, 2]
# bad score reset with layer: 2 | node index: 0 | path: [2, 0, 2]
# bad score reset with layer: 3 | node index: 2 | path: [2, 0, 2]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
#     uct sampling at layer 3, tree have 326 nodes
#  [2, 1, 3]
# 997
# bad score +1 with path: [2, 1, 3]
# bad score +1 with path: [2, 1, 3]
# bad score +1 with path: [2, 1, 3]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 1, 0]
# 998
# bad score +1 with path: [1, 1, 0]
# bad score +1 with path: [1, 1, 0]
# bad score +1 with path: [1, 1, 0]
#     uct sampling at layer 1, tree have 4 nodes
#     uct sampling at layer 2, tree have 26 nodes
# uniform sampling at layer 3, tree have 326 nodes
#  [1, 4, 4]
# guarded layer 1 nodes, will only prune 1 node
# failed search at uct score: 0.9354, percentile: 5.00%, currently pruning 40.00% of visited nodes
# guarded layer 1 nodes, will only prune 1 node
# guarded layer 1 nodes, will only prune 1 node
# 999
# bad score +1 with path: [1, 4, 4]
# bad score +1 with path: [1, 4, 4]
# bad score +1 with path: [1, 4, 4]
# pruning at uct percentile 0.9354
#     uct sampling at layer 1, tree have 3 nodes
#     uct sampling at layer 2, tree have 17 nodes
# uniform sampling at layer 3, tree have 211 nodes
#  [2, 2, 7]

# %%
visited_times_threshold_to_uct_sample = [4,2,1,1]
tree_layer_population_count = []
new_traverse_path = []
node_layer_population = search_augment.root.children
tree_layer_population = [search_augment.root]
for layer_index in range(search_augment.depth): 
    # uct need all the node of the TREE from this layer 
    tree_layer_population = search_augment.find_all_children_from_list(tree_layer_population)
    tree_layer_population_count.append(len(tree_layer_population))
    # base on section 3.4 P3, only sample when average visited time of children is larger than threshold 
    mean_visited_times = sum(map(lambda each: each.visited_times, node_layer_population)) / len(node_layer_population)
    if mean_visited_times > visited_times_threshold_to_uct_sample[layer_index]:
        raw = [search_augment.calculate_uct(each, tree_layer_population) / search_augment.eq6_tau for each in node_layer_population]
        exps = np.exp(raw)
        prob = exps / exps.sum()
        new_index = np.random.choice(np.arange(len(node_layer_population)), p=prob)
        out_str += f'    uct sampling at layer {layer_index+1}, tree have {len(tree_layer_population)} nodes\n'
    else:
        new_index = np.random.choice(np.arange(len(node_layer_population)))
        out_str += f'uniform sampling at layer {layer_index+1}, tree have {len(tree_layer_population)} nodes\n'
